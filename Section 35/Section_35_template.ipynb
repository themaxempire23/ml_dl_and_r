# %% [markdown]
# # Section 35: ML / DL / R Notebook\n\nThis starter notebook is ready for machine learning, deep learning, and R workflows.

# %%
# Python ML/DL starter imports\nimport numpy as np\nimport pandas as pd

# %%
# Optional deep learning imports (uncomment if installed)\n# import tensorflow as tf\n# import torch

# %% [markdown]
# ## R Starter (run in an R-enabled Jupyter environment)\n```r\n# install.packages(c('tidyverse', 'caret'))\nlibrary(tidyverse)\nlibrary(caret)\n```
